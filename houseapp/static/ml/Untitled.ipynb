# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %%
df = pd.read_csv("new.csv",encoding="gb2312")
# Out:
# /Users/weiruan/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318819 entries, 0 to 318818
# Data columns (total 26 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   url                  318819 non-null  object
#  1   id                   318819 non-null  object
#  2   Lng                  318819 non-null  float64
#  3   Lat                  318819 non-null  float64
#  4   Cid                  318819 non-null  float64
#  5   tradeTime            318819 non-null  object
#  6   DOM                  160849 non-null  float64
#  7   followers            318819 non-null  int64
#  8   totalPrice           318819 non-null  float64
#  9   price                318819 non-null  int64
#  10  square               318819 non-null  float64
#  11  livingRoom           318819 non-null  int64
#  12  drawingRoom          318819 non-null  int64
#  13  kitchen              318819 non-null  int64
#  14  bathRoom             318819 non-null  int64
# ...

# %%
df
# Out:
#                                                       url            id  \
# 0       https://bj.lianjia.com/chengjiao/101084782030....  101084782030
# 1       https://bj.lianjia.com/chengjiao/101086012217....  101086012217
# 2       https://bj.lianjia.com/chengjiao/101086041636....  101086041636
# 3       https://bj.lianjia.com/chengjiao/101086406841....  101086406841
# 4       https://bj.lianjia.com/chengjiao/101086920653....  101086920653
# ...                                                   ...           ...
# 318814  https://bj.lianjia.com/chengjiao/BJYZ92311192....  BJYZ92311192
# 318815  https://bj.lianjia.com/chengjiao/BJYZ92320171....  BJYZ92320171
# 318816  https://bj.lianjia.com/chengjiao/BJYZ92324217....  BJYZ92324217
# 318817  https://bj.lianjia.com/chengjiao/BJYZ92333313....  BJYZ92333313
# 318818  https://bj.lianjia.com/chengjiao/BJYZ92363553....  BJYZ92363553
#
#                Lng        Lat           Cid   tradeTime     DOM  followers  \
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of                                                       url            id  \
# 0       https://bj.lianjia.com/chengjiao/101084782030....  101084782030
# 1       https://bj.lianjia.com/chengjiao/101086012217....  101086012217
# 2       https://bj.lianjia.com/chengjiao/101086041636....  101086041636
# 3       https://bj.lianjia.com/chengjiao/101086406841....  101086406841
# 4       https://bj.lianjia.com/chengjiao/101086920653....  101086920653
# ...                                                   ...           ...
# 318814  https://bj.lianjia.com/chengjiao/BJYZ92311192....  BJYZ92311192
# 318815  https://bj.lianjia.com/chengjiao/BJYZ92320171....  BJYZ92320171
# 318816  https://bj.lianjia.com/chengjiao/BJYZ92324217....  BJYZ92324217
# 318817  https://bj.lianjia.com/chengjiao/BJYZ92333313....  BJYZ92333313
# 318818  https://bj.lianjia.com/chengjiao/BJYZ92363553....  BJYZ92363553
#
# ...

# %%
df.isna()
# Out:
#           url     id    Lng    Lat    Cid  tradeTime    DOM  followers  \
# 0       False  False  False  False  False      False  False      False
# 1       False  False  False  False  False      False  False      False
# 2       False  False  False  False  False      False  False      False
# 3       False  False  False  False  False      False  False      False
# 4       False  False  False  False  False      False  False      False
# ...       ...    ...    ...    ...    ...        ...    ...        ...
# 318814  False  False  False  False  False      False  False      False
# 318815  False  False  False  False  False      False   True      False
# 318816  False  False  False  False  False      False  False      False
# 318817  False  False  False  False  False      False   True      False
# 318818  False  False  False  False  False      False  False      False
#
#         totalPrice  price  ...  buildingType  constructionTime  \
# ...

# %%
(df.isnull().sum(axis=1)).value_counts()
# Out:
# 1    153669
# 0    152266
# 2     12637
# 3       194
# 4        53
# dtype: int64

# %%
df.isnull().sum(axis=0)
# Out:
# url                         0
# id                          0
# Lng                         0
# Lat                         0
# Cid                         0
# tradeTime                   0
# DOM                    157970
# followers                   0
# totalPrice                  0
# price                       0
# square                      0
# livingRoom                  0
# drawingRoom                 0
# kitchen                     0
# bathRoom                    0
# floor                       0
# buildingType             2021
# constructionTime        19283
# renovationCondition         0
# buildingStructure           0
# ladderRatio                 0
# elevator                    0
# fiveYearsProperty           0
# subway                      0
# district                    0
# communityAverage          463
# dtype: int64

# %%
# 根据分析目标，我们取出需要的列
df = df[['id','Lng' ,'Lat', 'tradeTime', 'totalPrice', 'square', 'livingRoom', 'drawingRoom', 'kitchen', 'bathRoom', 'floor', 'buildingType','renovationCondition','elevator', 'subway','district']]

# %%
#if the missing value of a piece of data exceeds 10%, the data will be invalid, so remove it
for index, row in df.iterrows():
    if((row.isnull().sum())>3):
        df=df.drop(index)

# %%
#At present, most of the data in DF are valid data
(df.isnull().sum(axis=1)).value_counts()
# Out:
# 0    316798
# 1      2021
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318819 entries, 0 to 318818
# Data columns (total 16 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id                   318819 non-null  object
#  1   Lng                  318819 non-null  float64
#  2   Lat                  318819 non-null  float64
#  3   tradeTime            318819 non-null  object
#  4   totalPrice           318819 non-null  float64
#  5   square               318819 non-null  float64
#  6   livingRoom           318819 non-null  int64
#  7   drawingRoom          318819 non-null  int64
#  8   kitchen              318819 non-null  int64
#  9   bathRoom             318819 non-null  int64
#  10  floor                318819 non-null  object
#  11  buildingType         316798 non-null  float64
#  12  renovationCondition  318819 non-null  int64
#  13  elevator             318819 non-null  int64
#  14  subway               318819 non-null  int64
# ...

# %%
(df.isnull().sum(axis=1)).value_counts()
# Out:
# 0    316798
# 1      2021
# dtype: int64

# %%
(df.isnull().sum(axis=0)).value_counts()
# Out:
# 0       15
# 2021     1
# dtype: int64

# %%
df.describe()
# Out:
#                  Lng            Lat     totalPrice         square  \
# count  318819.000000  318819.000000  318819.000000  318819.000000
# mean      116.418483      39.949593     349.051461      83.241400
# std         0.112031       0.091985     230.779782      37.234963
# min       116.072514      39.627030       0.100000       6.900000
# 25%       116.344985      39.893200     205.000000      57.900000
# 50%       116.416780      39.934527     294.000000      74.260000
# 75%       116.477581      40.003018     425.500000      98.710000
# max       116.732378      40.252758   18130.000000    1745.500000
#
#           livingRoom    drawingRoom        kitchen       bathRoom  \
# count  318819.000000  318819.000000  318819.000000  318819.000000
# mean        2.010370       1.171950       0.994338       1.188122
# std         0.776822       0.522287       0.106185       0.437544
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
df.mode()
# Out:
# /Users/weiruan/opt/anaconda3/lib/python3.8/site-packages/pandas/core/algorithms.py:897: UserWarning: Unable to sort modes: '<' not supported between instances of 'str' and 'int'
#   warn(f"Unable to sort modes: {err}")
#                   id         Lng        Lat  tradeTime  totalPrice  square  \
# 0       101100552192  116.343245  39.900529  2016/2/28       300.0    89.0
# 1       BJCY00414610         NaN        NaN        NaN         NaN     NaN
# 2       101100552196         NaN        NaN        NaN         NaN     NaN
# 3       BJXC90564167         NaN        NaN        NaN         NaN     NaN
# 4       BJCY89425751         NaN        NaN        NaN         NaN     NaN
# ...              ...         ...        ...        ...         ...     ...
# 318814  101101076472         NaN        NaN        NaN         NaN     NaN
# 318815  BJDX84374390         NaN        NaN        NaN         NaN     NaN
# 318816  101100552189         NaN        NaN        NaN         NaN     NaN
# ...

# %%
df['buildingType'].fillna(4, inplace=True)
# Out:
# /Users/weiruan/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:4517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
(df.isnull().sum(axis=0)).value_counts()
# Out:
# 0    16
# dtype: int64

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 318814    False
# 318815    False
# 318816    False
# 318817    False
# 318818    False
# Length: 318819, dtype: bool

# %% [markdown]
# 空缺值补充完毕

# %% [markdown]
# 查找异常值

# %%
df.describe()
# Out:
#                  Lng            Lat     totalPrice         square  \
# count  318819.000000  318819.000000  318819.000000  318819.000000
# mean      116.418483      39.949593     349.051461      83.241400
# std         0.112031       0.091985     230.779782      37.234963
# min       116.072514      39.627030       0.100000       6.900000
# 25%       116.344985      39.893200     205.000000      57.900000
# 50%       116.416780      39.934527     294.000000      74.260000
# 75%       116.477581      40.003018     425.500000      98.710000
# max       116.732378      40.252758   18130.000000    1745.500000
#
#           livingRoom    drawingRoom        kitchen       bathRoom  \
# count  318819.000000  318819.000000  318819.000000  318819.000000
# mean        2.010370       1.171950       0.994338       1.188122
# std         0.776822       0.522287       0.106185       0.437544
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
df.drop(df[df['totalPrice']  < 100].index, inplace = True)
# Out:
# /Users/weiruan/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df.describe()
# Out:
#                  Lng            Lat     totalPrice         square  \
# count  312517.000000  312517.000000  312517.000000  312517.000000
# mean      116.417761      39.949209     354.637593      83.750347
# std         0.110870       0.091052     229.649671      37.170631
# min       116.072514      39.627030     100.000000       6.900000
# 25%       116.345084      39.893339     209.000000      58.230000
# 50%       116.416543      39.934527     298.000000      74.890000
# 75%       116.476687      40.002169     430.000000      99.000000
# max       116.732378      40.252758   18130.000000    1745.500000
#
#           livingRoom    drawingRoom        kitchen       bathRoom  \
# count  312517.000000  312517.000000  312517.000000  312517.000000
# mean        2.021708       1.179670       0.995831       1.190825
# std         0.774479       0.518117       0.099010       0.438751
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
df['tradeTime'] = pd.to_datetime(df['tradeTime'])
# Out:
# <ipython-input-23-dfc4f6a7a077>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tradeTime'] = pd.to_datetime(df['tradeTime'])

# %%
df['year'] = df['tradeTime'].dt.year
df['year'].value_counts()
# Out:
# <ipython-input-24-bfcd547a0ff6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year'] = df['tradeTime'].dt.year
# 2016    90185
# 2015    69217
# 2017    43089
# 2013    38087
# 2012    34443
# 2014    32339
# 2011     4800
# 2018      221
# 2010      130
# 2002        3
# 2009        1
# 2008        1
# 2003        1
# Name: year, dtype: int64

# %%
# 删除数据量较少和年代久远的数据，统计2011-2017年数据
df.drop(df[df['year']  < 2011].index, inplace = True)
df.drop(df[df['year']  > 2017].index, inplace = True)
# Out:
# /Users/weiruan/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# /Users/weiruan/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 312160 entries, 0 to 318818
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id                   312160 non-null  object
#  1   Lng                  312160 non-null  float64
#  2   Lat                  312160 non-null  float64
#  3   tradeTime            312160 non-null  datetime64[ns]
#  4   totalPrice           312160 non-null  float64
#  5   square               312160 non-null  float64
#  6   livingRoom           312160 non-null  int64
#  7   drawingRoom          312160 non-null  int64
#  8   kitchen              312160 non-null  int64
#  9   bathRoom             312160 non-null  int64
#  10  floor                312160 non-null  object
#  11  buildingType         312160 non-null  float64
#  12  renovationCondition  312160 non-null  int64
#  13  elevator             312160 non-null  int64
# ...

# %%
df.describe(percentiles=[.1, .2, .6, .7, .8, .9, .95, .99])
# Out:
#                  Lng            Lat     totalPrice         square  \
# count  312160.000000  312160.000000  312160.000000  312160.000000
# mean      116.417885      39.949211     354.643330      83.747963
# std         0.110719       0.091057     229.603434      37.177795
# min       116.072514      39.627030     100.000000       6.900000
# 10%       116.295873      39.850451     158.000000      47.860000
# 20%       116.334596      39.882809     193.000000      55.900000
# 50%       116.416572      39.934527     298.000000      74.880000
# 60%       116.436169      39.960665     340.000000      85.400000
# 70%       116.460280      39.985697     396.500000      93.590000
# 80%       116.497474      40.038368     473.000000     106.510000
# 90%       116.576406      40.078668     610.000000     130.960000
# 95%       116.640545      40.093363     759.000000     151.000000
# 99%       116.691610      40.186753    1210.000000     212.151000
# ...

# %%
df.describe(include=['O'])
# Out:
#                   id   floor
# count         312160  312160
# unique        312160     200
# top     101101076479     中 6
# freq               1   33992

# %%
df['square'].value_counts(bins = 10)
# Out:
# (5.159999999999999, 180.76]    305604
# (180.76, 354.62]                 6396
# (354.62, 528.48]                  147
# (528.48, 702.34]                   10
# (876.2, 1050.06]                    2
# (1571.64, 1745.5]                   1
# (1397.78, 1571.64]                  0
# (1223.92, 1397.78]                  0
# (1050.06, 1223.92]                  0
# (702.34, 876.2]                     0
# Name: square, dtype: int64

# %%
df.drop(df[df['square']  > 350].index, inplace = True)
# Out:
# /Users/weiruan/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df.describe()
# Out:
#                  Lng            Lat     totalPrice         square  \
# count  311985.000000  311985.000000  311985.000000  311985.000000
# mean      116.417889      39.949194     353.661404      83.555610
# std         0.110724       0.091027     221.764615      36.164097
# min       116.072514      39.627030     100.000000       6.900000
# 25%       116.345153      39.893326     209.000000      58.210000
# 50%       116.416543      39.934527     298.000000      74.830000
# 75%       116.476687      40.002169     430.000000      98.960000
# max       116.732378      40.252758    4385.000000     350.000000
#
#           livingRoom    drawingRoom        kitchen       bathRoom  \
# count  311985.000000  311985.000000  311985.000000  311985.000000
# mean        2.020193       1.178964       0.996138       1.189496
# std         0.771824       0.517223       0.096285       0.434284
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
df['totalPrice'].value_counts(bins = 10)
# Out:
# (95.714, 528.5]     265334
# (528.5, 957.0]       39773
# (957.0, 1385.5]       5171
# (1385.5, 1814.0]      1245
# (1814.0, 2242.5]       308
# (2242.5, 2671.0]       104
# (2671.0, 3099.5]        30
# (3099.5, 3528.0]        13
# (3528.0, 3956.5]         4
# (3956.5, 4385.0]         3
# Name: totalPrice, dtype: int64

# %%
df.drop(df[df['totalPrice']  > 2000].index, inplace = True)
# Out:
# /Users/weiruan/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df.describe()
# Out:
#                  Lng            Lat     totalPrice         square  \
# count  311717.000000  311717.000000  311717.000000  311717.000000
# mean      116.417898      39.949186     351.885278      83.416857
# std         0.110752       0.091056     213.084801      35.837035
# min       116.072514      39.627030     100.000000       6.900000
# 25%       116.345153      39.893276     209.000000      58.200000
# 50%       116.416543      39.934527     298.000000      74.800000
# 75%       116.476687      40.002169     429.000000      98.890000
# max       116.732378      40.252758    2000.000000     350.000000
#
#           livingRoom    drawingRoom        kitchen       bathRoom  \
# count  311717.000000  311717.000000  311717.000000  311717.000000
# mean        2.018652       1.178248       0.996044       1.188119
# std         0.769994       0.516680       0.095855       0.431283
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
import matplotlib
import matplotlib.pyplot as plt


df.hist(bins=100, figsize=(20,15))
plt.show()

# %%
# Define a method that shows which columns that contains null values.
# This will help to check which colum needs a data cleaning. 
def NaN_Cols(dataframe):
    i=0
    for col in dataframe.columns:
        if dataframe[col].isnull().any():
            i+=1
            print(i,col)

# %%
# Define a method that returns the index numbers of null rows within a specific column with the given column name.
# This will help to apply the data cleaning operations.
def NaN_Rows_Number(dataframe,colName):
    NullRowsNumber = []
    (n_rows,n_cols) = dataframe.shape
    for idx,(index,row) in enumerate(dataframe.iterrows()):
        if pd.isnull(row[colName]):
            NullRowsNumber.append(index)
#     print('The indexs of NaN rows within this column is ',len(NullRowsNumber))
    return NullRowsNumber

# %%
print('totalPrice')
NaN_Cols(df)
# Out:
# totalPrice

# %% [markdown]
# Data Analyzing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 311717 entries, 0 to 318818
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id                   311717 non-null  object
#  1   Lng                  311717 non-null  float64
#  2   Lat                  311717 non-null  float64
#  3   tradeTime            311717 non-null  datetime64[ns]
#  4   totalPrice           311717 non-null  float64
#  5   square               311717 non-null  float64
#  6   livingRoom           311717 non-null  int64
#  7   drawingRoom          311717 non-null  int64
#  8   kitchen              311717 non-null  int64
#  9   bathRoom             311717 non-null  int64
#  10  floor                311717 non-null  object
#  11  buildingType         311717 non-null  float64
#  12  renovationCondition  311717 non-null  int64
#  13  elevator             311717 non-null  int64
# ...

# %%
df = df.reset_index()

# %%
df_dis = df.groupby('district', as_index = False) 
df_dis_count = df_dis.count()[['district','id']]
df_dis_count.rename(columns={'id':'num'},inplace = True)            # 各区房源数目
df_dis_mean_square = df_dis.mean()[['district','square']]           # 各区房源平均面积
df_dis_mean_comm = df_dis.mean()[['district','totalPrice']]   # 各区均价

df_dis_info = pd.merge(df_dis_count, pd.merge(df_dis_mean_square, df_dis_mean_comm, on = 'district'), on = 'district')
df_dis_info.sort_values('totalPrice', ascending = False, inplace = True)  # 总表按照各区房源数目降序排列
df_dis_info
# Out:
#     district     num      square  totalPrice
# 9         10   30983   67.437030  448.365520
# 0          1   16969   72.609738  439.271124
# 7          8   37881   79.237094  425.394171
# 6          7  105896   84.261927  367.754356
# 2          3    2284   97.938704  312.239842
# 1          2   28707   78.860405  302.146738
# 5          6   37229  101.365190  289.341065
# 8          9   11139   75.670829  272.410477
# 3          4   14817   88.074041  263.301647
# 4          5    2848   90.855098  255.975562
# 11        12    1463   86.068291  241.050444
# 10        11   13157   87.401251  238.248035
# 12        13    8344   97.386215  236.584935

# %%
# 各区房屋总价均值-有/无地铁(假设subway值为1时为有地铁) 
df_dis_sub = df[['id', 'district', 'subway','totalPrice']]
df_dis_sub = df_dis_sub.groupby(['district', 'subway']).mean()

print(df_dis_sub)
# Out:
#                  totalPrice
# district subway
# 1        0       442.813083
#          1       439.027274
# 2        0       306.423344
#          1       299.416807
# 3        0       360.958381
#          1       254.882936
# 4        0       261.314557
#          1       265.963651
# 5        0       238.743269
#          1       281.531037
# 6        0       283.052762
#          1       297.272103
# 7        0       350.688393
#          1       375.354239
# 8        0       418.953036
#          1       429.291877
# 9        0       271.479919
#          1       274.991260
# 10       0       436.953111
#          1       452.013621
# 11       0       232.906348
#          1       248.548587
# 12       0       240.797262
#          1       426.000000
# 13       0       242.523632
#          1       221.419506

# %%
# 均价⽇趋势
# 统计每⽇所有房源的平均单价
df_day_price = df.groupby('year').mean()['totalPrice']
df_day_price.sort_index(inplace=True) # 按照索引排序
df_day_price.plot() # 画出趋势图
# Out:
# <AxesSubplot:xlabel='year'>

# %%
# visualization
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.lineplot(x='renovationCondition', y='totalPrice', data=df)
# Out:
# <AxesSubplot:xlabel='renovationCondition', ylabel='totalPrice'>

# %%
df
# Out:
#          index            id         Lng        Lat  tradeTime  totalPrice  \
# 0            0  101084782030  116.475489  40.019520 2016-08-09       415.0
# 1            1  101086012217  116.453917  39.881534 2016-07-28       575.0
# 2            2  101086041636  116.561978  39.877145 2016-12-11      1030.0
# 3            3  101086406841  116.438010  40.076114 2016-09-30       297.5
# 4            4  101086920653  116.428392  39.886229 2016-08-28       392.0
# ...        ...           ...         ...        ...        ...         ...
# 311712  318814  BJYZ92311192  116.546899  39.755236 2016-06-10       350.0
# 311713  318815  BJYZ92320171  116.497474  39.810115 2016-06-10       108.8
# 311714  318816  BJYZ92324217  116.497256  39.804081 2016-06-05       359.0
# 311715  318817  BJYZ92333313  116.501794  39.799347 2016-06-12       720.0
# 311716  318818  BJYZ92363553  116.497474  39.810115 2016-06-11       450.0
#
#         square  livingRoom  drawingRoom  kitchen  bathRoom floor  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311717 entries, 0 to 311716
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   index                311717 non-null  int64
#  1   id                   311717 non-null  object
#  2   Lng                  311717 non-null  float64
#  3   Lat                  311717 non-null  float64
#  4   tradeTime            311717 non-null  datetime64[ns]
#  5   totalPrice           311717 non-null  float64
#  6   square               311717 non-null  float64
#  7   livingRoom           311717 non-null  int64
#  8   drawingRoom          311717 non-null  int64
#  9   kitchen              311717 non-null  int64
#  10  bathRoom             311717 non-null  int64
#  11  floor                311717 non-null  object
#  12  buildingType         311717 non-null  float64
#  13  renovationCondition  311717 non-null  int64
# ...

# %%
from sklearn import metrics
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
df = df[['Lng' ,'Lat', 'totalPrice', 'square', 'livingRoom', 'drawingRoom', 'kitchen', 'bathRoom', 'buildingType','renovationCondition','elevator', 'subway','district']]

# %%
scaler = MinMaxScaler()
df_scaled = pd.DataFrame(scaler.fit_transform(df),columns=df.columns,index=df.index)
df_scaled.describe()
# Out:
#                  Lng            Lat     totalPrice         square  \
# count  311717.000000  311717.000000  311717.000000  311717.000000
# mean        0.523417       0.514851       0.132571       0.223016
# std         0.167841       0.145520       0.112150       0.104451
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.413175       0.425498       0.057368       0.149519
# 50%         0.521363       0.491423       0.104211       0.197901
# 75%         0.612510       0.599524       0.173158       0.268114
# max         1.000000       1.000000       1.000000       1.000000
#
#           livingRoom    drawingRoom        kitchen       bathRoom  \
# count  311717.000000  311717.000000  311717.000000  311717.000000
# mean        0.224295       0.235650       0.332015       0.169731
# std         0.085555       0.103336       0.031952       0.061612
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
#The data set is divided into 9:1
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(df, test_size=0.2, random_state=30)
target = train_set['totalPrice'].copy()
train = train_set.drop('totalPrice',axis = 1)
X_train,x_test,y_train,y_true = train_test_split(train,target,test_size=0.1, random_state=30)
#print('set instances:', len(set), '\nTest instances: ', len(test_set))

# %%
train_y = train_set['totalPrice'].copy()
train_x = train_set.drop('totalPrice',axis = 1)

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import r2_score

# %%
n_neighbors=20

# %%
# k的值做折线图

# %%
knn = KNeighborsRegressor(n_neighbors=n_neighbors)

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=20)

# %%
y_pre_knn = knn.predict(x_test)

# %%
knn_score = r2_score(y_true,y_pre_knn)
display(knn_score)
# Out:
# 0.5931831857759366

# %%
y_true
# Out:
# 109415    196.0
# 251071    260.0
# 219688    126.0
# 184325    400.0
# 35055     376.0
#           ...
# 270178    213.0
# 207576    249.6
# 28904     519.0
# 204517    200.0
# 48046     206.0
# Name: totalPrice, Length: 24938, dtype: float64

# %%
y_pre_knn
# 对比测试集和数据集中的数据
# Out:
# array([211.175, 389.225, 173.055, ..., 521.665, 257.76 , 146.325])

# %%
import numpy as np
np.corrcoef(y_true, y_pre_knn)
# 真实值预测值散点图回归线
# Out:
# array([[1.        , 0.77019205],
#        [0.77019205, 1.        ]])

# %%
x_test
# Out:
#                Lng        Lat  square  livingRoom  drawingRoom  kitchen  \
# 109415  116.414019  40.121777  109.70           2            2        1
# 251071  116.312942  39.928393   56.86           2            1        1
# 219688  116.377942  39.847498   38.67           1            1        1
# 184325  116.491703  39.929224   91.22           2            2        1
# 35055   116.457117  39.971046   56.84           2            1        1
# ...            ...        ...     ...         ...          ...      ...
# 270178  116.198841  39.929432   68.11           1            1        1
# 207576  116.430535  39.793210   85.11           2            1        1
# 28904   116.477730  40.002156  112.09           2            1        1
# 204517  116.527286  39.829962   87.75           2            2        1
# 48046   116.291708  39.844912   35.20           1            0        1
#
#         bathRoom  buildingType  renovationCondition  elevator  subway  \
# ...

# %%
x1=x_test[0:1]

# %%
# 横坐标真实房价/纵坐标百分比误差mape
# 可视化
plt.plot(y_true,label='true')
plt.plot(y_pre_knn,label='knn')
plt.legend()

# %%
y_pre_knn
# Out:
# array([211.175, 389.225, 173.055, ..., 521.665, 257.76 , 146.325])

# %%
knn.predict(x1)
# Out:
# array([211.175])

# %%
# matrix 计算object型数据相关度

# %% [markdown]
# ---保存模型---

# %%
import pickle
pickle.dump(knn, open('model.pkl','wb'))
model = pickle.load(open('model.pkl','rb'))

# %%
# test
print(model.predict([[116.4, 40.1, 110, 2, 2, 1, 1, 4, 1, 0, 0, 6]]))
# Out:
# [197.555]
